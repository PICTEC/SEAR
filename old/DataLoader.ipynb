# %%
import os
import random

TRAIN = 160 # in paper - 9k
VALID = 20 # in paper - 80
TEST  = 20 # in paper - 80

LENGTH = 1248
SOURCE_SHAPE = [LENGTH, 129]
TARGET_SHAPE = [LENGTH, 257]

ROOT = os.path.expanduser("~")

PATH = os.path.join(ROOT, "DAE-libri")
CACHE_PATH = os.path.join(ROOT, "cache")
DATASETPATH = os.path.join(ROOT, ".dataset")

do_i_noise = True
NOISEPATH = os.path.join(ROOT, "NoiseDb")
SNR = 5

files = [os.path.join(PATH, x) for x in os.listdir(PATH) if x.endswith(".wav") and not x.endswith(".gsm.wav")]
train_files = random.sample(files, TRAIN)
valid_files = random.sample(list(set(files) - set(train_files)), VALID)
test_files = random.sample(list(set(files) - set(train_files) - set(valid_files)), TEST)
noise_files = [os.path.join(NOISEPATH, x) for x in os.listdir(NOISEPATH)]

# %%
### PREPARE AND LOAD

import numpy as np
import scipy.io.wavfile as sio
import tempfile
import subprocess

train_source, valid_source, test_source, train_target, valid_target, test_target, test_phase = [None] * 7
tempnam = tempfile.mktemp

def ennoise(data):
    SNR_ln = SNR / 10 * np.log(10)
    noise = sio.read(random.choice(noise_files))[1].astype(np.float32)
    data = data[:176000].astype(np.float32)
    if len(noise) <= len(data):
        print("NOISE TOO SHORT:", len(noise))
        noise = np.pad(noise, ((0, len(data) - len(noise)),),'constant')
    else:
        start = random.randint(0, len(noise) - len(data) - 1)
        noise = noise[start:start + len(data)]
    log_power_of_signal = np.log((data ** 2).mean())
    log_power_of_noise = np.log((noise ** 2).mean())
    gain_of_noise = np.exp(log_power_of_signal - SNR_ln - log_power_of_noise)   # SNR was miscalculated...
    if np.isnan(gain_of_noise):
        print("NAN gain - generating some random white noise")
        noise = np.random.normal(0, 1500, size=data.shape)
    else:
        noise = noise * gain_of_noise
    noised = data + noise
    if np.abs(noised).max() >= 2**15 - 1:
        print("Clipping noised by", np.abs(noised).max() - 2**15 - 1)
        noised = np.clip(noised, -1 * 2**15, 2**15 - 1)
    noised = noised.astype(np.int16)
    # print(gain_of_noise, log_power_of_signal, log_power_of_noise)
    # print("Mean amp of data: ", np.abs(data).mean())
    # print("Mean amp of noise: ", np.abs(noise).mean())
    # print("Mean amp of noised signal: ", np.abs(noised).mean())
    return noised

def prepare_data(filename):
    print(filename)
    data = sio.read(filename)[1] # .astype(np.float32) to generate noise in the experiment...
    if do_i_noise:
        data = ennoise(data)
    oldname = tempnam() + '.oldwav'
    sio.write(oldname, 16000, data)
    tmpname = tempnam() + '.amr-nb'
    newname = filename + ".gsm.wav"
    subprocess.Popen(['sox', oldname, '-C', '7', '-r', '8000', tmpname]).communicate()
    subprocess.Popen(['sox', tmpname, '-r', '16000', "-e", "signed", '-b', '16',  newname]).communicate()
    list(map(os.remove, [oldname, tmpname]))

[prepare_data(x) for x in train_files]
[prepare_data(x) for x in valid_files]
[prepare_data(x) for x in test_files]

train_source = np.zeros([TRAIN] + SOURCE_SHAPE, np.float32)
valid_source = np.zeros([VALID] + SOURCE_SHAPE, np.float32)
test_source  = np.zeros([TEST]  + SOURCE_SHAPE, np.float32)
train_target = np.zeros([TRAIN] + TARGET_SHAPE, np.float32)
valid_target = np.zeros([VALID] + TARGET_SHAPE, np.float32)
test_target  = np.zeros([TEST]  + TARGET_SHAPE, np.float32)
test_phase   = np.zeros([TEST]  + TARGET_SHAPE, np.float32)

window = np.hamming(512)

def get_data(source, target, index, filename, true_phase=None):
    print(filename)
    recording = sio.read(filename + ".gsm.wav")[1].astype(np.float32)
    recording /= 2**15
    for time in range(LENGTH):
        win = recording[128 * time : 128 * time + 512]
        if len(win) != 512:
            break
        fft = np.fft.rfft(window * win) / 512
        source[index, time, :] = -np.log(np.abs(fft) ** 2 + 2e-12)[:129]
    recording = sio.read(filename)[1].astype(np.float32)
    recording /= 2**15
    for time in range(LENGTH):
        win = recording[128 * time : 128 * time + 512]
        if len(win) != 512:
            break
        fft = np.fft.rfft(window * win) / 512
        target[index, time, :] = -np.log(np.abs(fft) ** 2 + 2e-12)
    if true_phase is not None:
        true_phase = np.angle(fft)


[get_data(train_source, train_target, ix, x) for ix, x in enumerate(train_files)]
[get_data(valid_source, valid_target, ix, x) for ix, x in enumerate(valid_files)]
[get_data(test_source,  test_target,  ix, x, true_phase=test_phase) for ix, x in enumerate(test_files)]
# Out:
# /home/zantyr/DAE-libri/3299.wav
# Clipping noised by 6254.01953125
# /home/zantyr/DAE-libri/19841.wav
# /home/zantyr/DAE-libri/5577.wav
# Clipping noised by 25469.8671875
# /home/zantyr/DAE-libri/15442.wav
# Clipping noised by 12686.6484375
# /home/zantyr/DAE-libri/17585.wav
# /home/zantyr/DAE-libri/4180.wav
# /home/zantyr/DAE-libri/13932.wav
# Clipping noised by 57837.5625
# /home/zantyr/DAE-libri/27133.wav
# Clipping noised by 148755.5
# /home/zantyr/DAE-libri/3014.wav
# /home/zantyr/DAE-libri/15982.wav
# /home/zantyr/DAE-libri/18769.wav
# /home/zantyr/DAE-libri/12133.wav
# /home/zantyr/DAE-libri/25380.wav
# /home/zantyr/DAE-libri/1314.wav
# Clipping noised by 23474.44140625
# /home/zantyr/DAE-libri/13876.wav
# /home/zantyr/DAE-libri/6630.wav
# Clipping noised by 4787.09765625
# /home/zantyr/DAE-libri/27345.wav
# Clipping noised by 133932.390625
# /home/zantyr/DAE-libri/2838.wav
# Clipping noised by 69982.21875
# /home/zantyr/DAE-libri/14460.wav
# /home/zantyr/DAE-libri/9113.wav
# /home/zantyr/DAE-libri/25376.wav
# /home/zantyr/DAE-libri/26504.wav
# /home/zantyr/DAE-libri/24707.wav
# Clipping noised by 16796.0625
# /home/zantyr/DAE-libri/26217.wav
# /home/zantyr/DAE-libri/24385.wav
# Clipping noised by 22407.26171875
# /home/zantyr/DAE-libri/26487.wav
# /home/zantyr/DAE-libri/2567.wav
# /home/zantyr/DAE-libri/26760.wav
# /home/zantyr/DAE-libri/7857.wav
# Clipping noised by 10891.18359375
# /home/zantyr/DAE-libri/6961.wav
# Clipping noised by 593672.25
# /home/zantyr/DAE-libri/1684.wav
# /home/zantyr/DAE-libri/18120.wav
# /home/zantyr/DAE-libri/13395.wav
# /home/zantyr/DAE-libri/228.wav
# Clipping noised by 89218.3828125
# /home/zantyr/DAE-libri/14941.wav
# /home/zantyr/DAE-libri/12857.wav
# Clipping noised by 113242.53125
# /home/zantyr/DAE-libri/16758.wav
# /home/zantyr/DAE-libri/24214.wav
# /home/zantyr/DAE-libri/13177.wav
# Clipping noised by 88077.46875
# /home/zantyr/DAE-libri/17080.wav
# /home/zantyr/DAE-libri/9243.wav
# /home/zantyr/DAE-libri/22691.wav
# /home/zantyr/DAE-libri/2588.wav
# /home/zantyr/DAE-libri/6863.wav
# /home/zantyr/DAE-libri/22193.wav
# /home/zantyr/DAE-libri/2517.wav
# /home/zantyr/DAE-libri/13212.wav
# /home/zantyr/DAE-libri/63.wav
# /home/zantyr/DAE-libri/516.wav
# Clipping noised by 27030.86328125
# /home/zantyr/DAE-libri/4024.wav
# /home/zantyr/DAE-libri/26518.wav
# /home/zantyr/DAE-libri/445.wav
# Clipping noised by 18950.4453125
# /home/zantyr/DAE-libri/17775.wav
# /home/zantyr/DAE-libri/25052.wav
# Clipping noised by 167535.0625
# /home/zantyr/DAE-libri/18478.wav
# /home/zantyr/DAE-libri/16165.wav
# /home/zantyr/DAE-libri/250.wav
# Clipping noised by 275732.21875
# /home/zantyr/DAE-libri/14277.wav
# /home/zantyr/DAE-libri/27532.wav
# Clipping noised by 15823.7734375
# /home/zantyr/DAE-libri/27646.wav
# Clipping noised by 4153.0390625
# /home/zantyr/DAE-libri/21868.wav
# /home/zantyr/DAE-libri/4262.wav
# /home/zantyr/DAE-libri/7146.wav
# Clipping noised by 9768.234375
# /home/zantyr/DAE-libri/18556.wav
# /home/zantyr/DAE-libri/21934.wav
# /home/zantyr/DAE-libri/4289.wav
# /home/zantyr/DAE-libri/3143.wav
# /home/zantyr/DAE-libri/24139.wav
# /home/zantyr/DAE-libri/10663.wav
# /home/zantyr/DAE-libri/14590.wav
# Clipping noised by 67630.5078125
# /home/zantyr/DAE-libri/11821.wav
# /home/zantyr/DAE-libri/5675.wav
# /home/zantyr/DAE-libri/18865.wav
# /home/zantyr/DAE-libri/11334.wav
# Clipping noised by 315970.1875
# /home/zantyr/DAE-libri/12793.wav
# /home/zantyr/DAE-libri/22613.wav
# Clipping noised by 33164.9609375
# /home/zantyr/DAE-libri/22087.wav
# Clipping noised by 20898.5234375
# /home/zantyr/DAE-libri/27659.wav
# Clipping noised by 172260.453125
# /home/zantyr/DAE-libri/22328.wav
# NOISE TOO SHORT: 160000
# Clipping noised by 216975.875
# /home/zantyr/DAE-libri/17379.wav
# Clipping noised by 34333.8828125
# /home/zantyr/DAE-libri/17882.wav
# Clipping noised by 11577.453125
# /home/zantyr/DAE-libri/27141.wav
# /home/zantyr/DAE-libri/22076.wav
# /home/zantyr/DAE-libri/20312.wav
# /home/zantyr/DAE-libri/23721.wav
# /home/zantyr/DAE-libri/8299.wav
# Clipping noised by 147197.140625
# /home/zantyr/DAE-libri/7258.wav
# /home/zantyr/DAE-libri/17062.wav
# /home/zantyr/DAE-libri/14178.wav
# /home/zantyr/DAE-libri/15034.wav
# /home/zantyr/DAE-libri/2386.wav
# /home/zantyr/DAE-libri/7428.wav
# /home/zantyr/DAE-libri/17311.wav
# NOISE TOO SHORT: 160000
# Clipping noised by 1287834.75
# /home/zantyr/DAE-libri/25657.wav
# /home/zantyr/DAE-libri/14336.wav
# /home/zantyr/DAE-libri/10681.wav
# Clipping noised by 32992.75
# /home/zantyr/DAE-libri/7374.wav
# /home/zantyr/DAE-libri/22294.wav
# /home/zantyr/DAE-libri/4692.wav
# Clipping noised by 8262.12890625
# /home/zantyr/DAE-libri/16612.wav
# /home/zantyr/DAE-libri/1806.wav
# /home/zantyr/DAE-libri/13426.wav
# /home/zantyr/DAE-libri/5878.wav
# /home/zantyr/DAE-libri/5940.wav
# NOISE TOO SHORT: 160000
# Clipping noised by 209986.265625
# /home/zantyr/DAE-libri/12189.wav
# /home/zantyr/DAE-libri/12338.wav
# /home/zantyr/DAE-libri/9292.wav
# /home/zantyr/DAE-libri/2983.wav
# Clipping noised by 42566.8125
# /home/zantyr/DAE-libri/26567.wav
# Clipping noised by 15567.69921875
# /home/zantyr/DAE-libri/8133.wav
# /home/zantyr/DAE-libri/16056.wav
# Clipping noised by 184314.96875
# /home/zantyr/DAE-libri/5415.wav
# /home/zantyr/DAE-libri/27637.wav
# /home/zantyr/DAE-libri/15896.wav
# /home/zantyr/DAE-libri/25386.wav
# NOISE TOO SHORT: 160000
# Clipping noised by 55646.71875
# /home/zantyr/DAE-libri/1182.wav
# /home/zantyr/DAE-libri/259.wav
# Clipping noised by 9427.36328125
# /home/zantyr/DAE-libri/20099.wav
# /home/zantyr/DAE-libri/21010.wav
# /home/zantyr/DAE-libri/10700.wav
# /home/zantyr/DAE-libri/28271.wav
# /home/zantyr/DAE-libri/10463.wav
# /home/zantyr/DAE-libri/20497.wav
# /home/zantyr/DAE-libri/17401.wav
# Clipping noised by 144172.8125
# /home/zantyr/DAE-libri/13033.wav
# /home/zantyr/DAE-libri/5476.wav
# /home/zantyr/DAE-libri/10788.wav
# /home/zantyr/DAE-libri/5800.wav
# /home/zantyr/DAE-libri/24386.wav
# /home/zantyr/DAE-libri/4233.wav
# Clipping noised by 206178.46875
# /home/zantyr/DAE-libri/6629.wav
# /home/zantyr/DAE-libri/16254.wav
# /home/zantyr/DAE-libri/9332.wav
# Clipping noised by 19832.28125
# /home/zantyr/DAE-libri/10120.wav
# /home/zantyr/DAE-libri/7068.wav
# NOISE TOO SHORT: 160000
# Clipping noised by 125471.140625
# /home/zantyr/DAE-libri/25232.wav
# /home/zantyr/DAE-libri/26374.wav
# /home/zantyr/DAE-libri/6575.wav
# Clipping noised by 119000.875
# /home/zantyr/DAE-libri/24832.wav
# /home/zantyr/DAE-libri/15061.wav
# /home/zantyr/DAE-libri/19880.wav
# Clipping noised by 31548.3984375
# /home/zantyr/DAE-libri/454.wav
# NOISE TOO SHORT: 160000
# Clipping noised by 411321.375
# /home/zantyr/DAE-libri/16212.wav
# /home/zantyr/DAE-libri/7292.wav
# /home/zantyr/DAE-libri/10723.wav
# Clipping noised by 190846.640625
# /home/zantyr/DAE-libri/21134.wav
# /home/zantyr/DAE-libri/9685.wav
# /home/zantyr/DAE-libri/9555.wav
# Clipping noised by 55025.4921875
# /home/zantyr/DAE-libri/12086.wav
# /home/zantyr/DAE-libri/9768.wav
# /home/zantyr/DAE-libri/17939.wav
# Clipping noised by 15506.3671875
# /home/zantyr/DAE-libri/7350.wav
# /home/zantyr/DAE-libri/3719.wav
# /home/zantyr/DAE-libri/23244.wav
# /home/zantyr/DAE-libri/27124.wav
# /home/zantyr/DAE-libri/17937.wav
# Clipping noised by 46352.7421875
# /home/zantyr/DAE-libri/7606.wav
# /home/zantyr/DAE-libri/17261.wav
# /home/zantyr/DAE-libri/26677.wav
# /home/zantyr/DAE-libri/22060.wav
# /home/zantyr/DAE-libri/8503.wav
# /home/zantyr/DAE-libri/4220.wav
# /home/zantyr/DAE-libri/22589.wav
# /home/zantyr/DAE-libri/13151.wav
# Clipping noised by 9171.78125
# /home/zantyr/DAE-libri/5593.wav
# Clipping noised by 816.5859375
# /home/zantyr/DAE-libri/24037.wav
# /home/zantyr/DAE-libri/929.wav
# /home/zantyr/DAE-libri/21067.wav
# Clipping noised by 119424.5625
# /home/zantyr/DAE-libri/13020.wav
# /home/zantyr/DAE-libri/18302.wav
# Clipping noised by 66733.4765625
# /home/zantyr/DAE-libri/25710.wav
# Clipping noised by 38310.015625
# /home/zantyr/DAE-libri/1046.wav
# /home/zantyr/DAE-libri/3358.wav
# /home/zantyr/DAE-libri/26486.wav
# /home/zantyr/DAE-libri/17208.wav
# Clipping noised by 39957.3359375
# /home/zantyr/DAE-libri/22257.wav
# Clipping noised by 49442.3046875
# /home/zantyr/DAE-libri/25145.wav
# Clipping noised by 50997.171875
# /home/zantyr/DAE-libri/16139.wav
# Clipping noised by 1655.421875
# /home/zantyr/DAE-libri/17920.wav
# Clipping noised by 25044.2265625
# /home/zantyr/DAE-libri/15723.wav
# /home/zantyr/DAE-libri/10346.wav
# Clipping noised by 113567.625
# /home/zantyr/DAE-libri/8535.wav
# /home/zantyr/DAE-libri/1640.wav
# /home/zantyr/DAE-libri/11337.wav
# Clipping noised by 84964.9921875
# /home/zantyr/DAE-libri/8964.wav
# /home/zantyr/DAE-libri/23081.wav
# /home/zantyr/DAE-libri/11416.wav
# /home/zantyr/DAE-libri/11958.wav
# /home/zantyr/DAE-libri/165.wav
# Clipping noised by 61439.1171875
# /home/zantyr/DAE-libri/9461.wav
# /home/zantyr/DAE-libri/14353.wav
# /home/zantyr/DAE-libri/12717.wav
# /home/zantyr/DAE-libri/22977.wav
# Clipping noised by 181893.90625
# /home/zantyr/DAE-libri/25379.wav
# /home/zantyr/DAE-libri/27394.wav
# Clipping noised by 53.15625
# /home/zantyr/DAE-libri/8586.wav
# /home/zantyr/DAE-libri/20551.wav
# Clipping noised by 11481.2421875
# /home/zantyr/DAE-libri/24158.wav
# Clipping noised by 82806.984375
# /home/zantyr/DAE-libri/3757.wav
# /home/zantyr/DAE-libri/14403.wav
# Clipping noised by 50208.921875
# /home/zantyr/DAE-libri/3299.wav
# /home/zantyr/DAE-libri/19841.wav
# /home/zantyr/DAE-libri/5577.wav
# /home/zantyr/DAE-libri/15442.wav
# /home/zantyr/DAE-libri/17585.wav
# /home/zantyr/DAE-libri/4180.wav
# /home/zantyr/DAE-libri/13932.wav
# /home/zantyr/DAE-libri/27133.wav
# /home/zantyr/DAE-libri/3014.wav
# /home/zantyr/DAE-libri/15982.wav
# /home/zantyr/DAE-libri/18769.wav
# /home/zantyr/DAE-libri/12133.wav
# /home/zantyr/DAE-libri/25380.wav
# /home/zantyr/DAE-libri/1314.wav
# /home/zantyr/DAE-libri/13876.wav
# /home/zantyr/DAE-libri/6630.wav
# /home/zantyr/DAE-libri/27345.wav
# /home/zantyr/DAE-libri/2838.wav
# /home/zantyr/DAE-libri/14460.wav
# /home/zantyr/DAE-libri/9113.wav
# /home/zantyr/DAE-libri/25376.wav
# /home/zantyr/DAE-libri/26504.wav
# /home/zantyr/DAE-libri/24707.wav
# /home/zantyr/DAE-libri/26217.wav
# /home/zantyr/DAE-libri/24385.wav
# /home/zantyr/DAE-libri/26487.wav
# /home/zantyr/DAE-libri/2567.wav
# /home/zantyr/DAE-libri/26760.wav
# /home/zantyr/DAE-libri/7857.wav
# /home/zantyr/DAE-libri/6961.wav
# /home/zantyr/DAE-libri/1684.wav
# /home/zantyr/DAE-libri/18120.wav
# /home/zantyr/DAE-libri/13395.wav
# /home/zantyr/DAE-libri/228.wav
# /home/zantyr/DAE-libri/14941.wav
# /home/zantyr/DAE-libri/12857.wav
# /home/zantyr/DAE-libri/16758.wav
# /home/zantyr/DAE-libri/24214.wav
# /home/zantyr/DAE-libri/13177.wav
# /home/zantyr/DAE-libri/17080.wav
# /home/zantyr/DAE-libri/9243.wav
# /home/zantyr/DAE-libri/22691.wav
# /home/zantyr/DAE-libri/2588.wav
# /home/zantyr/DAE-libri/6863.wav
# /home/zantyr/DAE-libri/22193.wav
# /home/zantyr/DAE-libri/2517.wav
# /home/zantyr/DAE-libri/13212.wav
# /home/zantyr/DAE-libri/63.wav
# /home/zantyr/DAE-libri/516.wav
# /home/zantyr/DAE-libri/4024.wav
# /home/zantyr/DAE-libri/26518.wav
# /home/zantyr/DAE-libri/445.wav
# /home/zantyr/DAE-libri/17775.wav
# /home/zantyr/DAE-libri/25052.wav
# /home/zantyr/DAE-libri/18478.wav
# /home/zantyr/DAE-libri/16165.wav
# /home/zantyr/DAE-libri/250.wav
# /home/zantyr/DAE-libri/14277.wav
# /home/zantyr/DAE-libri/27532.wav
# /home/zantyr/DAE-libri/27646.wav
# /home/zantyr/DAE-libri/21868.wav
# /home/zantyr/DAE-libri/4262.wav
# /home/zantyr/DAE-libri/7146.wav
# /home/zantyr/DAE-libri/18556.wav
# /home/zantyr/DAE-libri/21934.wav
# /home/zantyr/DAE-libri/4289.wav
# /home/zantyr/DAE-libri/3143.wav
# /home/zantyr/DAE-libri/24139.wav
# /home/zantyr/DAE-libri/10663.wav
# /home/zantyr/DAE-libri/14590.wav
# /home/zantyr/DAE-libri/11821.wav
# /home/zantyr/DAE-libri/5675.wav
# /home/zantyr/DAE-libri/18865.wav
# /home/zantyr/DAE-libri/11334.wav
# /home/zantyr/DAE-libri/12793.wav
# /home/zantyr/DAE-libri/22613.wav
# /home/zantyr/DAE-libri/22087.wav
# /home/zantyr/DAE-libri/27659.wav
# /home/zantyr/DAE-libri/22328.wav
# /home/zantyr/DAE-libri/17379.wav
# /home/zantyr/DAE-libri/17882.wav
# /home/zantyr/DAE-libri/27141.wav
# /home/zantyr/DAE-libri/22076.wav
# /home/zantyr/DAE-libri/20312.wav
# /home/zantyr/DAE-libri/23721.wav
# /home/zantyr/DAE-libri/8299.wav
# /home/zantyr/DAE-libri/7258.wav
# /home/zantyr/DAE-libri/17062.wav
# /home/zantyr/DAE-libri/14178.wav
# /home/zantyr/DAE-libri/15034.wav
# /home/zantyr/DAE-libri/2386.wav
# /home/zantyr/DAE-libri/7428.wav
# /home/zantyr/DAE-libri/17311.wav
# /home/zantyr/DAE-libri/25657.wav
# /home/zantyr/DAE-libri/14336.wav
# /home/zantyr/DAE-libri/10681.wav
# /home/zantyr/DAE-libri/7374.wav
# /home/zantyr/DAE-libri/22294.wav
# /home/zantyr/DAE-libri/4692.wav
# /home/zantyr/DAE-libri/16612.wav
# /home/zantyr/DAE-libri/1806.wav
# /home/zantyr/DAE-libri/13426.wav
# /home/zantyr/DAE-libri/5878.wav
# /home/zantyr/DAE-libri/5940.wav
# /home/zantyr/DAE-libri/12189.wav
# /home/zantyr/DAE-libri/12338.wav
# /home/zantyr/DAE-libri/9292.wav
# /home/zantyr/DAE-libri/2983.wav
# /home/zantyr/DAE-libri/26567.wav
# /home/zantyr/DAE-libri/8133.wav
# /home/zantyr/DAE-libri/16056.wav
# /home/zantyr/DAE-libri/5415.wav
# /home/zantyr/DAE-libri/27637.wav
# /home/zantyr/DAE-libri/15896.wav
# /home/zantyr/DAE-libri/25386.wav
# /home/zantyr/DAE-libri/1182.wav
# /home/zantyr/DAE-libri/259.wav
# /home/zantyr/DAE-libri/20099.wav
# /home/zantyr/DAE-libri/21010.wav
# /home/zantyr/DAE-libri/10700.wav
# /home/zantyr/DAE-libri/28271.wav
# /home/zantyr/DAE-libri/10463.wav
# /home/zantyr/DAE-libri/20497.wav
# /home/zantyr/DAE-libri/17401.wav
# /home/zantyr/DAE-libri/13033.wav
# /home/zantyr/DAE-libri/5476.wav
# /home/zantyr/DAE-libri/10788.wav
# /home/zantyr/DAE-libri/5800.wav
# /home/zantyr/DAE-libri/24386.wav
# /home/zantyr/DAE-libri/4233.wav
# /home/zantyr/DAE-libri/6629.wav
# /home/zantyr/DAE-libri/16254.wav
# /home/zantyr/DAE-libri/9332.wav
# /home/zantyr/DAE-libri/10120.wav
# /home/zantyr/DAE-libri/7068.wav
# /home/zantyr/DAE-libri/25232.wav
# /home/zantyr/DAE-libri/26374.wav
# /home/zantyr/DAE-libri/6575.wav
# /home/zantyr/DAE-libri/24832.wav
# /home/zantyr/DAE-libri/15061.wav
# /home/zantyr/DAE-libri/19880.wav
# /home/zantyr/DAE-libri/454.wav
# /home/zantyr/DAE-libri/16212.wav
# /home/zantyr/DAE-libri/7292.wav
# /home/zantyr/DAE-libri/10723.wav
# /home/zantyr/DAE-libri/21134.wav
# /home/zantyr/DAE-libri/9685.wav
# /home/zantyr/DAE-libri/9555.wav
# /home/zantyr/DAE-libri/12086.wav
# /home/zantyr/DAE-libri/9768.wav
# /home/zantyr/DAE-libri/17939.wav
# /home/zantyr/DAE-libri/7350.wav
# /home/zantyr/DAE-libri/3719.wav
# /home/zantyr/DAE-libri/23244.wav
# /home/zantyr/DAE-libri/27124.wav
# /home/zantyr/DAE-libri/17937.wav
# /home/zantyr/DAE-libri/7606.wav
# /home/zantyr/DAE-libri/17261.wav
# /home/zantyr/DAE-libri/26677.wav
# /home/zantyr/DAE-libri/22060.wav
# /home/zantyr/DAE-libri/8503.wav
# /home/zantyr/DAE-libri/4220.wav
# /home/zantyr/DAE-libri/22589.wav
# /home/zantyr/DAE-libri/13151.wav
# /home/zantyr/DAE-libri/5593.wav
# /home/zantyr/DAE-libri/24037.wav
# /home/zantyr/DAE-libri/929.wav
# /home/zantyr/DAE-libri/21067.wav
# /home/zantyr/DAE-libri/13020.wav
# /home/zantyr/DAE-libri/18302.wav
# /home/zantyr/DAE-libri/25710.wav
# /home/zantyr/DAE-libri/1046.wav
# /home/zantyr/DAE-libri/3358.wav
# /home/zantyr/DAE-libri/26486.wav
# /home/zantyr/DAE-libri/17208.wav
# /home/zantyr/DAE-libri/22257.wav
# /home/zantyr/DAE-libri/25145.wav
# /home/zantyr/DAE-libri/16139.wav
# /home/zantyr/DAE-libri/17920.wav
# /home/zantyr/DAE-libri/15723.wav
# /home/zantyr/DAE-libri/10346.wav
# /home/zantyr/DAE-libri/8535.wav
# /home/zantyr/DAE-libri/1640.wav
# /home/zantyr/DAE-libri/11337.wav
# /home/zantyr/DAE-libri/8964.wav
# /home/zantyr/DAE-libri/23081.wav
# /home/zantyr/DAE-libri/11416.wav
# /home/zantyr/DAE-libri/11958.wav
# /home/zantyr/DAE-libri/165.wav
# /home/zantyr/DAE-libri/9461.wav
# /home/zantyr/DAE-libri/14353.wav
# /home/zantyr/DAE-libri/12717.wav
# /home/zantyr/DAE-libri/22977.wav
# /home/zantyr/DAE-libri/25379.wav
# /home/zantyr/DAE-libri/27394.wav
# /home/zantyr/DAE-libri/8586.wav
# /home/zantyr/DAE-libri/20551.wav
# /home/zantyr/DAE-libri/24158.wav
# /home/zantyr/DAE-libri/3757.wav
# /home/zantyr/DAE-libri/14403.wav
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
if not os.path.exists(DATASETPATH):
    os.mkdir(DATASETPATH)
np.save(os.path.join(DATASETPATH, "train_source.bin"), train_source)
np.save(os.path.join(DATASETPATH, "valid_source.bin"), valid_source)
np.save(os.path.join(DATASETPATH, "test_source.bin"), test_source)
np.save(os.path.join(DATASETPATH, "train_target.bin"), train_target)
np.save(os.path.join(DATASETPATH, "valid_target.bin"), valid_target)
np.save(os.path.join(DATASETPATH, "test_target.bin"), test_target)
np.save(os.path.join(DATASETPATH, "test_phase.bin"), test_phase)
